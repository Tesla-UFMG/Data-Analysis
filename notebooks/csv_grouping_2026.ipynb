# %%
import pandas as pd
from datetime import datetime
import numpy as np

# %%
# colunas que vao para o arquivo FULL final
# nomes ja refatorados
columns = [
    "timestamp",
    "ACCEL_LONGITUDINAL", # eixo Z
    "ACCEL_LATERAL", # eixo X
    "ACCEL_NORMAL", # eixo Y
    "VEL_ANGULAR_YAW", # eixo giro Y
    "VEL_ANGULAR_PITCH", # eixo giro X
    "VEL_ANGULAR_ROLL", # eixo giro Z
    "AIR_MINUS",
    "AIR_PLUS",
    "GLV_VOLTAGE",
    "SHUNT_CURRENT",
    "MAX_CELL_VOLTAGE",
    "MIN_CELL_VOLTAGE",
    "MAX_CELL_TEMP",
    "TRACTIVE_VOLTAGE",
    "GNSS_TIMESTAMP",
    "LATITUDE",
    "LONGITUDE",
    "SPEED_AVG",
    "STEERING_WHEEL",
    "THROTTLE",
    "BRAKE",
    "TORQUE_GAIN",
    "TORQUE_DECREASE_R",
    "TORQUE_DECREASE_L",
    "SPEED_FL",
    "SPEED_FR",
    "SPEED_RL",
    "SPEED_RR",
    "RPM_L_MOTOR",
    "TORQUE_L_MOTOR",
    "POWER_L_MOTOR",
    "LEFT_MOTOR_CURRENT",
    "RPM_R_MOTOR",
    "TORQUE_R_MOTOR",
    "POWER_R_MOTOR",
    "RIGHT_MOTOR_CURRENT",
    "ENERGY_R_MOTOR",
    "OVERLOAD_R_MOTOR",
    "TEMPERATURE1_R",
    "TEMPERATURE2_R",
    "LOST_MSG_R_MOTOR",
    "BUS_OFF_R_MOTOR",
    "CAN_STATE_R_MOTOR",
    "INV_STATE_R_MOTOR",
    "FAILURE_R_MOTOR",
    "ALARM_R_MOTOR",
    "BMS_ERRORMASK",
    "BMS_ERROR_LOG1",
    "BMS_ERROR_LOG2",
    "BMS_ERROR_LOG3",
    "BMS_ERROR_LOG4",
    "BMS_ERROR_LOG5",
    "ERROR_SUM_S1",
    "ERROR_SUM_S2",
    "ERROR_SUM_S3",
    "ERROR_SUM_S4",
    "ERROR_SUM_S5",
    "BMS_MODE",
    "ADDR_CELL_VOLT_MIN",
    "ADDR_STACK_VOLT_MIN",
    "ADDR_MIN_VOLTAGE",
    "ADDR_CELL_VOLT_MAX",
    "ADDR_STACK_VOLT_MAX",
    "ADDR_MAX_VOLTAGE",
    'ADDR_CELL_TEMP_MAX',
    'ADDR_STACK_TEMP_MAX',
    'ADDR_MAX_TEMPERATURE',
    "DESIRED_YAW",
    "MAX_YAW",
    "ECU_MODE",
    "CONTROL_EVENT_FLAG_1",
    "CONTROL_EVENT_FLAG_2",
    "DISTANCE_P_ODOM",
    "DISTANCE_T_ODOM",
    "SET_POINT_LONGITUDINAL",
    "SET_POINT_LATERAL",
    "KP",
    "TI",
    "SLIP",
    "RIGHT_MOTOR_TEMPERATURE",
    "LEFT_MOTOR_TEMPERATURE",
    "STACK_1_CELL_1_VOLTAGE",
    "STACK_1_CELL_2_VOLTAGE",
    "STACK_1_CELL_3_VOLTAGE",
    "STACK_1_CELL_4_VOLTAGE",
    "STACK_2_CELL_1_VOLTAGE",
    "STACK_2_CELL_2_VOLTAGE",
    "STACK_2_CELL_3_VOLTAGE",
    "STACK_2_CELL_4_VOLTAGE",
    "STACK_3_CELL_1_VOLTAGE",
    "STACK_3_CELL_2_VOLTAGE",
    "STACK_3_CELL_3_VOLTAGE",
    "STACK_3_CELL_4_VOLTAGE",
    "STACK_4_CELL_1_VOLTAGE",
    "STACK_4_CELL_2_VOLTAGE",
    "STACK_4_CELL_3_VOLTAGE",
    "STACK_4_CELL_4_VOLTAGE",
    "STACK_5_CELL_1_VOLTAGE",
    "STACK_5_CELL_2_VOLTAGE",
    "STACK_5_CELL_3_VOLTAGE",
    "STACK_5_CELL_4_VOLTAGE",
    "STACK_6_CELL_1_VOLTAGE",
    "STACK_6_CELL_2_VOLTAGE",
    "STACK_6_CELL_3_VOLTAGE",
    "STACK_6_CELL_4_VOLTAGE",
    "STACK_1_CELL_1_TEMPERATURE",
    "STACK_1_CELL_2_TEMPERATURE",
    "STACK_1_CELL_3_TEMPERATURE",
    "STACK_1_CELL_4_TEMPERATURE",
    "STACK_2_CELL_1_TEMPERATURE",
    "STACK_2_CELL_2_TEMPERATURE",
    "STACK_2_CELL_3_TEMPERATURE",
    "STACK_2_CELL_4_TEMPERATURE",
    "STACK_3_CELL_1_TEMPERATURE",
    "STACK_3_CELL_2_TEMPERATURE",
    "STACK_3_CELL_3_TEMPERATURE",
    "STACK_3_CELL_4_TEMPERATURE",
    "STACK_4_CELL_1_TEMPERATURE",
    "STACK_4_CELL_2_TEMPERATURE",
    "STACK_4_CELL_3_TEMPERATURE",
    "STACK_4_CELL_4_TEMPERATURE",
    "STACK_5_CELL_1_TEMPERATURE",
    "STACK_5_CELL_2_TEMPERATURE",
    "STACK_5_CELL_3_TEMPERATURE",
    "STACK_5_CELL_4_TEMPERATURE",
    "STACK_6_CELL_1_TEMPERATURE",
    "STACK_6_CELL_2_TEMPERATURE",
    "STACK_6_CELL_3_TEMPERATURE",
    "STACK_6_CELL_4_TEMPERATURE",
]

# %%
# timestamps de interesse
# nome: (inicio, fim)

## ------ MINEIRÃO 28/06/2026 ------- ###
interest_timestamps = {
    # miguelito1
    "miguelito1_skidpad1": (1782566013928, 1782566059056),
    "miguelito1_skidpad2": (1782566164435, 1782566206499),
    "miguelito1_skidpad3": (1782566306598, 1782566371194),
    "miguelito1_skidpad4": (1782566451610, 1782566523683),
    "miguelito1_skidpad5": (1782566595555, 1782566666712),
    "miguelito1_skidpad6": (1782566712607, 1782566793422),
    "miguelito1_skidpad7": (1782566835435, 1782566939016),
    "miguelito1_skidpad8": (1782567016185, 1782567087789),
    "miguelito1_skidpad9": (1782567223275, 1782567312370),
    "miguelito1_skidpad10": (1782567423427, 1782567467556),
    "miguelito1_skidpad11": (1782567552785, 1782567637250),
    
    # boson1-3
    "boson1_skidpad1": (1782579536886, 1782579715869),
    "boson2_skidpad2": (1782582532632, 1782582646802),
    "boson2_skidpad3": (1782582779557, 1782582868750),
    "boson2_skidpad4": (1782583173009, 1782583211244),
    "boson3_skidpad5": (1782582532632, 1782582645836),
    "boson3_skidpad6": (1782582780807, 1782582868399),
    "boson3_skidpad7": (1782583173009, 1782583210228),
    
    # miguelito2
    "miguelito2_aceleracao1": (1782588568631, 1782588596658),
    "miguelito2_aceleracao2": (1782588646299, 1782588672261),
    
    # miguelito3
    "miguelito3_skidpad12": (1782590173581, 1782590222206),
    "miguelito3_skidpad13": (1782590319429, 1782590394411),
    "miguelito3_skidpad14": (1782590472229, 1782590525850),
    "miguelito3_skidpad15": (1782590780770, 1782591044169),
    "miguelito3_skidpad16": (1782591287832, 1782591343468),
    "miguelito3_skidpad17": (1782591568313, 1782591626829),
    "miguelito3_skidpad18": (1782591831707, 1782591904880),
    "miguelito3_skidpad19": (1782592115951, 1782592199198),
}

# %%
full_df = pd.DataFrame([], columns=columns)
full_df
# Out:
# Empty DataFrame
# Columns: [timestamp, ACCEL_LONGITUDINAL, ACCEL_LATERAL, ACCEL_NORMAL, VEL_ANGULAR_YAW, VEL_ANGULAR_PITCH, VEL_ANGULAR_ROLL, AIR_MINUS, AIR_PLUS, GLV_VOLTAGE, SHUNT_CURRENT, MAX_CELL_VOLTAGE, MIN_CELL_VOLTAGE, MAX_CELL_TEMP, TRACTIVE_VOLTAGE, GNSS_TIMESTAMP, LATITUDE, LONGITUDE, SPEED_AVG, STEERING_WHEEL, THROTTLE, BRAKE, TORQUE_GAIN, TORQUE_DECREASE_R, TORQUE_DECREASE_L, SPEED_FL, SPEED_FR, SPEED_RL, SPEED_RR, RPM_L_MOTOR, TORQUE_L_MOTOR, POWER_L_MOTOR, LEFT_MOTOR_CURRENT, RPM_R_MOTOR, TORQUE_R_MOTOR, POWER_R_MOTOR, RIGHT_MOTOR_CURRENT, ENERGY_R_MOTOR, OVERLOAD_R_MOTOR, TEMPERATURE1_R, TEMPERATURE2_R, LOST_MSG_R_MOTOR, BUS_OFF_R_MOTOR, CAN_STATE_R_MOTOR, INV_STATE_R_MOTOR, FAILURE_R_MOTOR, ALARM_R_MOTOR, BMS_ERRORMASK, BMS_ERROR_LOG1, BMS_ERROR_LOG2, BMS_ERROR_LOG3, BMS_ERROR_LOG4, BMS_ERROR_LOG5, ERROR_SUM_S1, ERROR_SUM_S2, ERROR_SUM_S3, ERROR_SUM_S4, ERROR_SUM_S5, BMS_MODE, ADDR_CELL_VOLT_MIN, ADDR_STACK_VOLT_MIN, ADDR_MIN_VOLTAGE, ADDR_CELL_VOLT_MAX, ADDR_STACK_VOLT_MAX, ADDR_MAX_VOLTAGE, ADDR_CELL_TEMP_MAX, ADDR_STACK_TEMP_MAX, ADDR_MAX_TEMPERATURE, DESIRED_YAW, MAX_YAW, ECU_MODE, CONTROL_EVENT_FLAG_1, CONTROL_EVENT_FLAG_2, DISTANCE_P_ODOM, DISTANCE_T_ODOM, SET_POINT_LONGITUDINAL, SET_POINT_LATERAL, KP, TI, SLIP, RIGHT_MOTOR_TEMPERATURE, LEFT_MOTOR_TEMPERATURE, STACK_1_CELL_1_VOLTAGE, STACK_1_CELL_2_VOLTAGE, STACK_1_CELL_3_VOLTAGE, STACK_1_CELL_4_VOLTAGE, STACK_2_CELL_1_VOLTAGE, STACK_2_CELL_2_VOLTAGE, STACK_2_CELL_3_VOLTAGE, STACK_2_CELL_4_VOLTAGE, STACK_3_CELL_1_VOLTAGE, STACK_3_CELL_2_VOLTAGE, STACK_3_CELL_3_VOLTAGE, STACK_3_CELL_4_VOLTAGE, STACK_4_CELL_1_VOLTAGE, STACK_4_CELL_2_VOLTAGE, STACK_4_CELL_3_VOLTAGE, STACK_4_CELL_4_VOLTAGE, STACK_5_CELL_1_VOLTAGE, STACK_5_CELL_2_VOLTAGE, ...]
# Index: []
#
# [0 rows x 130 columns]

# %%
file_names = [
    "1_GYROSCOPE.csv",
    "2_ACCELEROMETER.csv",
    "8_AIR_GVL_CURRENT.csv",
    "10_TOTAL_VOLTAGE_STACK_46.csv",
    "11_ACCUMULATOR_PARAMS.csv",
    "12_GNSS_TIMESTAMP.csv",
    "13_GNSS_LATITUDE.csv",
    "14_GNSS_LONGITUDE.csv",
    "16_DRIVER_INPUTS.csv",
    "17_REF_TORQUE.csv",
    "18_WHEEL_SPEED.csv",
    "20_LEFT_MOTOR_TRACTIVE.csv",
    "21_LEFT_MOTOR_CURRENT.csv",
    "25_RIGHT_MOTOR_TRACTIVE.csv",
    "26_RIGHT_MOTOR_CURRENT.csv",
    "27_RIGHT_MOTOR_ENERGY_TEMP.csv",
    "28_RIGHT_MOTOR_COMMUNICATION.csv",
    "29_RIGHT_MOTOR_STATE.csv",
    "34_STACK_VOLTAGE_1.csv",
    "35_STACK_VOLTAGE_2.csv",
    "36_STACK_VOLTAGE_3.csv",
    "37_STACK_VOLTAGE_4.csv",
    "38_STACK_VOLTAGE_5.csv",
    "39_STACK_VOLTAGE_6.csv",
    "40_STACK_TEMPERATURE_1.csv",
    "41_STACK_TEMPERATURE_2.csv",
    "42_STACK_TEMPERATURE_3.csv",
    "43_STACK_TEMPERATURE_4.csv",
    "44_STACK_TEMPERATURE_5.csv",
    "45_STACK_TEMPERATURE_6.csv",
    "46_BMS_ERROR_LOG_1.csv",
    "47_BMS_ERROR_LOG_2.csv",
    "48_ERROR_SUM_SLAVE_1.csv",
    "49_ERROR_SUM_SLAVE_2.csv",
    "50_BMS_MODE.csv",
    "63_ADDR_VOLT_MIN.csv",
    "64_ADDR_VOLT_MAX.csv",
    "65_ADDR_MAX_TEMP.csv",
    "66_DESIRED_YAW.csv",
    "67_ECU_MODE.csv",
    "68_TORQUE_GAIN.csv",
    "69_CONTROL_EVENTS.csv",
    "70_HODOMETER.csv",
    "71_SET_POINT.csv",
    "72_SLIP_RATE.csv",
    "73_TEMPERATURE_NTC_1.csv"
]

folder_names  = [
    # "../data/dados_telemetria/mineirao_27062026/miguelito1",
    # "../data/dados_telemetria/mineirao_27062026/miguelito2",
    # "../data/dados_telemetria/mineirao_27062026/miguelito3",
    # "../data/dados_telemetria/mineirao_27062026/boson1",
    "../data/dados_telemetria/mineirao_27062026/boson2",
    # "../data/dados_telemetria/mineirao_27062026/boson3",
]

full_folder = "../data/dados_telemetria/mineirao_27062026/full"

# %%
for file_name in file_names:
    print(file_name + "...")
    dfs_list = []
    for folder in folder_names:
        partial_df = pd.read_csv(f"{folder}/{file_name}")
        
        if not partial_df.empty:
            dfs_list.append(partial_df)
    
    if len(dfs_list) == 0:
        print(f"empty dfs_list at {file_name}")

    combined_df = pd.concat(dfs_list, ignore_index=True)
    combined_df.to_csv(f"{full_folder}/{"FULL_" + file_name}", index=False)
# Out:
# 1_GYROSCOPE.csv...
# 2_ACCELEROMETER.csv...
# 8_AIR_GVL_CURRENT.csv...
# 10_TOTAL_VOLTAGE_STACK_46.csv...
# 11_ACCUMULATOR_PARAMS.csv...
# 12_GNSS_TIMESTAMP.csv...
# 13_GNSS_LATITUDE.csv...
# 14_GNSS_LONGITUDE.csv...
# 16_DRIVER_INPUTS.csv...
# 17_REF_TORQUE.csv...
# 18_WHEEL_SPEED.csv...
# 20_LEFT_MOTOR_TRACTIVE.csv...
# 21_LEFT_MOTOR_CURRENT.csv...
# 25_RIGHT_MOTOR_TRACTIVE.csv...
# 26_RIGHT_MOTOR_CURRENT.csv...
# 27_RIGHT_MOTOR_ENERGY_TEMP.csv...
# 28_RIGHT_MOTOR_COMMUNICATION.csv...
# 29_RIGHT_MOTOR_STATE.csv...
# 34_STACK_VOLTAGE_1.csv...
# 35_STACK_VOLTAGE_2.csv...
# 36_STACK_VOLTAGE_3.csv...
# 37_STACK_VOLTAGE_4.csv...
# 38_STACK_VOLTAGE_5.csv...
# 39_STACK_VOLTAGE_6.csv...
# 40_STACK_TEMPERATURE_1.csv...
# 41_STACK_TEMPERATURE_2.csv...
# 42_STACK_TEMPERATURE_3.csv...
# 43_STACK_TEMPERATURE_4.csv...
# 44_STACK_TEMPERATURE_5.csv...
# 45_STACK_TEMPERATURE_6.csv...
# 46_BMS_ERROR_LOG_1.csv...
# 47_BMS_ERROR_LOG_2.csv...
# 48_ERROR_SUM_SLAVE_1.csv...
# 49_ERROR_SUM_SLAVE_2.csv...
# 50_BMS_MODE.csv...
# 63_ADDR_VOLT_MIN.csv...
# 64_ADDR_VOLT_MAX.csv...
# 65_ADDR_MAX_TEMP.csv...
# 66_DESIRED_YAW.csv...
# 67_ECU_MODE.csv...
# 68_TORQUE_GAIN.csv...
# 69_CONTROL_EVENTS.csv...
# 70_HODOMETER.csv...
# 71_SET_POINT.csv...
# 72_SLIP_RATE.csv...
# 73_TEMPERATURE_NTC_1.csv...

# %%
# quais colunas precisa refatorar para colocar no arquivo final FULL.csv
# (old_name, new_name)
columns_rename_map = {
    "FULL_1_GYROSCOPE.csv": [("GYRO_Z", "VEL_ANGULAR_ROLL"), ("GYRO_X", "VEL_ANGULAR_PITCH"), ("GYRO_Y", "VEL_ANGULAR_YAW")],
    "FULL_2_ACCELEROMETER.csv": [("ACCEL_Z", "ACCEL_LONGITUDINAL"), ("ACCEL_X", "ACCEL_LATERAL"), ("ACCEL_Y", "ACCEL_NORMAL")],
    "FULL_8_AIR_GVL_CURRENT.csv": [("GVL", "GLV_VOLTAGE"), ("CURRENT", "SHUNT_CURRENT")],
    "FULL_12_GNSS_TIMESTAMP.csv": [("TIMESTAMP", "GNSS_TIMESTAMP")],
    "FULL_17_REF_TORQUE.csv": [("TORQUE_DECRASE_L", "TORQUE_DECREASE_L")],
    "FULL_20_LEFT_MOTOR_TRACTIVE.csv": [("SPEED_L_MOTOR", "RPM_L_MOTOR")],
    "FULL_25_RIGHT_MOTOR_TRACTIVE.csv": [("SPEED_R_MOTOR", "RPM_R_MOTOR")],
    "FULL_46_BMS_ERROR_LOG_1.csv": [("ERRROMASK", "BMS_ERRORMASK"), ("ERROR_LOG1", "BMS_ERROR_LOG1"), ("ERROR_LOG2", "BMS_ERROR_LOG2"), ("ERROR_LOG3", "BMS_ERROR_LOG3")],
    "FULL_47_BMS_ERROR_LOG_2.csv": [("ERROR_LOG4", "BMS_ERROR_LOG4"), ("ERROR_LOG5", "BMS_ERROR_LOG5")],
    "FULL_63_ADDR_VOLT_MIN.csv": [("MIN_VOLTAGE", "ADDR_MIN_VOLTAGE")],
    "FULL_64_ADDR_VOLT_MAX.csv": [("MAX_VOLTAGE", "ADDR_MAX_VOLTAGE")],
    "FULL_65_ADDR_MAX_TEMP.csv": [("MAX_TEMPERATURE", "ADDR_MAX_TEMPERATURE")],
    "FULL_73_TEMPERATURE_NTC_1.csv": [("NTC_1", "RIGHT_MOTOR_TEMPERATURE"), ("NTC_2", "LEFT_MOTOR_TEMPERATURE")],
    "FULL_34_STACK_VOLTAGE_1.csv": [
        ("CELL_1", "STACK_1_CELL_1_VOLTAGE"), ("CELL_2", "STACK_1_CELL_2_VOLTAGE"), ("CELL_3", "STACK_1_CELL_3_VOLTAGE"), ("CELL_4", "STACK_1_CELL_4_VOLTAGE")
    ],
    "FULL_35_STACK_VOLTAGE_2.csv": [
        ("CELL_1", "STACK_2_CELL_1_VOLTAGE"), ("CELL_2", "STACK_2_CELL_2_VOLTAGE"), ("CELL_3", "STACK_2_CELL_3_VOLTAGE"), ("CELL_4", "STACK_2_CELL_4_VOLTAGE")
    ],
    "FULL_36_STACK_VOLTAGE_3.csv": [
        ("CELL_1", "STACK_3_CELL_1_VOLTAGE"), ("CELL_2", "STACK_3_CELL_2_VOLTAGE"), ("CELL_3", "STACK_3_CELL_3_VOLTAGE"), ("CELL_4", "STACK_3_CELL_4_VOLTAGE")
    ],
    "FULL_37_STACK_VOLTAGE_4.csv": [
        ("CELL_1", "STACK_4_CELL_1_VOLTAGE"), ("CELL_2", "STACK_4_CELL_2_VOLTAGE"), ("CELL_3", "STACK_4_CELL_3_VOLTAGE"), ("CELL_4", "STACK_4_CELL_4_VOLTAGE")
    ],
    "FULL_38_STACK_VOLTAGE_5.csv": [
        ("CELL_1", "STACK_5_CELL_1_VOLTAGE"), ("CELL_2", "STACK_5_CELL_2_VOLTAGE"), ("CELL_3", "STACK_5_CELL_3_VOLTAGE"), ("CELL_4", "STACK_5_CELL_4_VOLTAGE")
    ],
    "FULL_39_STACK_VOLTAGE_6.csv": [
        ("CELL_1", "STACK_6_CELL_1_VOLTAGE"), ("CELL_2", "STACK_6_CELL_2_VOLTAGE"), ("CELL_3", "STACK_6_CELL_3_VOLTAGE"), ("CELL_4", "STACK_6_CELL_4_VOLTAGE")
    ],
    "FULL_40_STACK_TEMPERATURE_1.csv": [
        ("CELL_1", "STACK_1_CELL_1_TEMPERATURE"), ("CELL_2", "STACK_1_CELL_2_TEMPERATURE"), ("CELL_3", "STACK_1_CELL_3_TEMPERATURE"), ("CELL_4", "STACK_1_CELL_4_TEMPERATURE")
    ],
    "FULL_41_STACK_TEMPERATURE_2.csv": [
        ("CELL_1", "STACK_2_CELL_1_TEMPERATURE"), ("CELL_2", "STACK_2_CELL_2_TEMPERATURE"), ("CELL_3", "STACK_2_CELL_3_TEMPERATURE"), ("CELL_4", "STACK_2_CELL_4_TEMPERATURE")
    ],
    "FULL_42_STACK_TEMPERATURE_3.csv": [
        ("CELL_1", "STACK_3_CELL_1_TEMPERATURE"), ("CELL_2", "STACK_3_CELL_2_TEMPERATURE"), ("CELL_3", "STACK_3_CELL_3_TEMPERATURE"), ("CELL_4", "STACK_3_CELL_4_TEMPERATURE")
    ],
    "FULL_43_STACK_TEMPERATURE_4.csv": [
        ("CELL_1", "STACK_4_CELL_1_TEMPERATURE"), ("CELL_2", "STACK_4_CELL_2_TEMPERATURE"), ("CELL_3", "STACK_4_CELL_3_TEMPERATURE"), ("CELL_4", "STACK_4_CELL_4_TEMPERATURE")
    ],
    "FULL_44_STACK_TEMPERATURE_5.csv": [
        ("CELL_1", "STACK_5_CELL_1_TEMPERATURE"), ("CELL_2", "STACK_5_CELL_2_TEMPERATURE"), ("CELL_3", "STACK_5_CELL_3_TEMPERATURE"), ("CELL_4", "STACK_5_CELL_4_TEMPERATURE")
    ],
    "FULL_45_STACK_TEMPERATURE_6.csv": [
        ("CELL_1", "STACK_6_CELL_1_TEMPERATURE"), ("CELL_2", "STACK_6_CELL_2_TEMPERATURE"), ("CELL_3", "STACK_6_CELL_3_TEMPERATURE"), ("CELL_4", "STACK_6_CELL_4_TEMPERATURE")
    ],
}

# quais colunas vou efetivamente usar dos full individuais - nomes refatorados ja
# isso remove colunas nao usadas (ex: index, 4,5,6, ...)
file_columns_map = {
    "FULL_1_GYROSCOPE.csv": ['VEL_ANGULAR_ROLL', 'VEL_ANGULAR_PITCH', 'VEL_ANGULAR_YAW'],
    "FULL_2_ACCELEROMETER.csv": ['ACCEL_LONGITUDINAL', 'ACCEL_LATERAL', 'ACCEL_NORMAL'],
    "FULL_8_AIR_GVL_CURRENT.csv": ["AIR_MINUS","AIR_PLUS","GLV_VOLTAGE","SHUNT_CURRENT"],
    "FULL_11_ACCUMULATOR_PARAMS.csv": ["MAX_CELL_VOLTAGE","MIN_CELL_VOLTAGE","MAX_CELL_TEMP","TRACTIVE_VOLTAGE"],
    "FULL_12_GNSS_TIMESTAMP.csv": ["GNSS_TIMESTAMP"],
    "FULL_13_GNSS_LATITUDE.csv": ['LATITUDE'],
    "FULL_14_GNSS_LONGITUDE.csv": ['LONGITUDE'],
    "FULL_16_DRIVER_INPUTS.csv": ["SPEED_AVG","STEERING_WHEEL","THROTTLE","BRAKE"],
    "FULL_17_REF_TORQUE.csv": ["TORQUE_GAIN","TORQUE_DECREASE_R","TORQUE_DECREASE_L"],
    "FULL_18_WHEEL_SPEED.csv": ["SPEED_FL","SPEED_FR","SPEED_RL","SPEED_RR"],
    "FULL_20_LEFT_MOTOR_TRACTIVE.csv": ["RPM_L_MOTOR","TORQUE_L_MOTOR"],
    "FULL_21_LEFT_MOTOR_CURRENT.csv": ['LEFT_MOTOR_CURRENT'],
    "FULL_25_RIGHT_MOTOR_TRACTIVE.csv": ["RPM_R_MOTOR","TORQUE_R_MOTOR"],
    "FULL_26_RIGHT_MOTOR_CURRENT.csv": ['RIGHT_MOTOR_CURRENT'],
    "FULL_27_RIGHT_MOTOR_ENERGY_TEMP.csv": ["ENERGY_R_MOTOR","OVERLOAD_R_MOTOR","TEMPERATURE1_R","TEMPERATURE2_R"],
    "FULL_28_RIGHT_MOTOR_COMMUNICATION.csv": ['LOST_MSG_R_MOTOR','BUS_OFF_R_MOTOR','CAN_STATE_R_MOTOR'],
    "FULL_29_RIGHT_MOTOR_STATE.csv": ['INV_STATE_R_MOTOR','FAILURE_R_MOTOR','ALARM_R_MOTOR'],
    "FULL_34_STACK_VOLTAGE_1.csv": ['STACK_1_CELL_1_VOLTAGE', 'STACK_1_CELL_2_VOLTAGE', 'STACK_1_CELL_3_VOLTAGE', 'STACK_1_CELL_4_VOLTAGE'],
    "FULL_35_STACK_VOLTAGE_2.csv": ['STACK_2_CELL_1_VOLTAGE', 'STACK_2_CELL_2_VOLTAGE', 'STACK_2_CELL_3_VOLTAGE', 'STACK_2_CELL_4_VOLTAGE'],
    "FULL_36_STACK_VOLTAGE_3.csv": ['STACK_3_CELL_1_VOLTAGE', 'STACK_3_CELL_2_VOLTAGE', 'STACK_3_CELL_3_VOLTAGE', 'STACK_3_CELL_4_VOLTAGE'],
    "FULL_37_STACK_VOLTAGE_4.csv": ['STACK_4_CELL_1_VOLTAGE', 'STACK_4_CELL_2_VOLTAGE', 'STACK_4_CELL_3_VOLTAGE', 'STACK_4_CELL_4_VOLTAGE'],
    "FULL_38_STACK_VOLTAGE_5.csv": ['STACK_5_CELL_1_VOLTAGE', 'STACK_5_CELL_2_VOLTAGE', 'STACK_5_CELL_3_VOLTAGE', 'STACK_5_CELL_4_VOLTAGE'],
    "FULL_39_STACK_VOLTAGE_6.csv": ['STACK_6_CELL_1_VOLTAGE', 'STACK_6_CELL_2_VOLTAGE', 'STACK_6_CELL_3_VOLTAGE', 'STACK_6_CELL_4_VOLTAGE'],
    "FULL_40_STACK_TEMPERATURE_1.csv": ['STACK_1_CELL_1_TEMPERATURE', 'STACK_1_CELL_2_TEMPERATURE', 'STACK_1_CELL_3_TEMPERATURE', 'STACK_1_CELL_4_TEMPERATURE'],
    "FULL_41_STACK_TEMPERATURE_2.csv": ['STACK_2_CELL_1_TEMPERATURE', 'STACK_2_CELL_2_TEMPERATURE', 'STACK_2_CELL_3_TEMPERATURE', 'STACK_2_CELL_4_TEMPERATURE'],
    "FULL_42_STACK_TEMPERATURE_3.csv": ['STACK_3_CELL_1_TEMPERATURE', 'STACK_3_CELL_2_TEMPERATURE', 'STACK_3_CELL_3_TEMPERATURE', 'STACK_3_CELL_4_TEMPERATURE'],
    "FULL_43_STACK_TEMPERATURE_4.csv": ['STACK_4_CELL_1_TEMPERATURE', 'STACK_4_CELL_2_TEMPERATURE', 'STACK_4_CELL_3_TEMPERATURE', 'STACK_4_CELL_4_TEMPERATURE'],
    "FULL_44_STACK_TEMPERATURE_5.csv": ['STACK_5_CELL_1_TEMPERATURE', 'STACK_5_CELL_2_TEMPERATURE', 'STACK_5_CELL_3_TEMPERATURE', 'STACK_5_CELL_4_TEMPERATURE'],
    "FULL_45_STACK_TEMPERATURE_6.csv": ['STACK_6_CELL_1_TEMPERATURE', 'STACK_6_CELL_2_TEMPERATURE', 'STACK_6_CELL_3_TEMPERATURE', 'STACK_6_CELL_4_TEMPERATURE'],
    "FULL_46_BMS_ERROR_LOG_1.csv": ["BMS_ERRORMASK", "BMS_ERROR_LOG1", "BMS_ERROR_LOG2", "BMS_ERROR_LOG3"],
    "FULL_47_BMS_ERROR_LOG_2.csv": ["BMS_ERROR_LOG4", "BMS_ERROR_LOG5"],
    "FULL_48_ERROR_SUM_SLAVE_1.csv": ["ERROR_SUM_S1","ERROR_SUM_S2","ERROR_SUM_S3"],
    "FULL_49_ERROR_SUM_SLAVE_2.csv": ["ERROR_SUM_S4","ERROR_SUM_S5","ERROR_SUM_S6"],
    "FULL_50_BMS_MODE.csv": ['BMS_MODE'],
    "FULL_63_ADDR_VOLT_MIN.csv": ['ADDR_CELL_VOLT_MIN','ADDR_STACK_VOLT_MIN','ADDR_MIN_VOLTAGE'],
    "FULL_64_ADDR_VOLT_MAX.csv":  ['ADDR_CELL_VOLT_MAX','ADDR_STACK_VOLT_MAX','ADDR_MAX_VOLTAGE'],
    "FULL_65_ADDR_MAX_TEMP.csv": ['ADDR_CELL_TEMP_MAX','ADDR_STACK_TEMP_MAX','ADDR_MAX_TEMPERATURE'],
    "FULL_66_DESIRED_YAW.csv": ['DESIRED_YAW','MAX_YAW'],
    "FULL_67_ECU_MODE.csv": ['ECU_MODE'],
    "FULL_69_CONTROL_EVENTS.csv": ['CONTROL_EVENT_FLAG_1','CONTROL_EVENT_FLAG_2'],
    "FULL_70_HODOMETER.csv": ['DISTANCE_P_ODOM'],
    "FULL_71_SET_POINT.csv": ['SET_POINT_LONGITUDINAL','SET_POINT_LATERAL'],
    "FULL_72_SLIP_RATE.csv": ['KP','TI','SLIP'],
    "FULL_73_TEMPERATURE_NTC_1.csv": ['RIGHT_MOTOR_TEMPERATURE','LEFT_MOTOR_TEMPERATURE']
}

# %%
# configura os limites maximos de cada coluna, para remover ruidos
# (min, max)
# valores ja processados
columns_list_threshholds = {
    "timestamp": (None, None),
    "ACCEL_LONGITUDINAL": (-10, 10),
    "ACCEL_LATERAL": (-10, 10),
    "ACCEL_NORMAL": (-10, 10),
    "VEL_ANGULAR_YAW": (-500, 500),
    "VEL_ANGULAR_PITCH": (-500, 500),
    "VEL_ANGULAR_ROLL": (-500, 500),
    'AIR_MINUS': (-10,10),
    'AIR_PLUS': (-10,10),
    'GLV_VOLTAGE': (-30,30),
    'SHUNT_CURRENT': (-1000,1000),
    'MAX_CELL_VOLTAGE': (-10,10),
    'MIN_CELL_VOLTAGE': (-10,10),
    'MAX_CELL_TEMP': (-100,100),
    'TRACTIVE_VOLTAGE': (-10,120),
    'GNSS_TIMESTAMP': (None, None),
    "LATITUDE": (-90, 90),
    "LONGITUDE": (-180, 180),
    'SPEED_AVG': (-100,100),
    'STEERING_WHEEL': (-100,100),
    'THROTTLE': (-1000,1000),
    'BRAKE': (-1000,1000),
    'TORQUE_GAIN': (-1000,1000),
    'TORQUE_DECREASE_R': (-1000,1000),
    'TORQUE_DECREASE_L': (-1000,1000),
    'SPEED_FL':(-100, 8000),
    'SPEED_FR':(-100, 8000),
    'SPEED_RL':(-100, 8000),
    'SPEED_RR':(-100, 8000),
    'RPM_L_MOTOR': (-100, 8000),
    'TORQUE_L_MOTOR': (-200, 200),
    'LEFT_MOTOR_CURRENT': (-1000, 1000),
    'RPM_R_MOTOR': (-100, 8000),
    'TORQUE_R_MOTOR': (-200, 200),
    'RIGHT_MOTOR_CURRENT': (-1000, 1000),
    'ENERGY_R_MOTOR': (None, None),
    'OVERLOAD_R_MOTOR': (None, None),
    'TEMPERATURE1_R': (-1000, 1000),
    'TEMPERATURE2_R': (-1000, 1000),
    'LOST_MSG_R_MOTOR': (None, None),
    'BUS_OFF_R_MOTOR': (None, None),
    'CAN_STATE_R_MOTOR': (None, None),
    'INV_STATE_R_MOTOR': (None, None),
    'FAILURE_R_MOTOR': (None, None),
    'ALARM_R_MOTOR': (None, None),
    'STACK_1_CELL_1_VOLTAGE': (-10, 10),
    'STACK_1_CELL_2_VOLTAGE': (-10, 10),
    'STACK_1_CELL_3_VOLTAGE': (-10, 10),
    'STACK_1_CELL_4_VOLTAGE': (-10, 10),
    'STACK_2_CELL_1_VOLTAGE': (-10, 10),
    'STACK_2_CELL_2_VOLTAGE': (-10, 10),
    'STACK_2_CELL_3_VOLTAGE': (-10, 10),
    'STACK_2_CELL_4_VOLTAGE': (-10, 10),
    'STACK_3_CELL_1_VOLTAGE': (-10, 10),
    'STACK_3_CELL_2_VOLTAGE': (-10, 10),
    'STACK_3_CELL_3_VOLTAGE': (-10, 10),
    'STACK_3_CELL_4_VOLTAGE': (-10, 10),
    'STACK_4_CELL_1_VOLTAGE': (-10, 10),
    'STACK_4_CELL_2_VOLTAGE': (-10, 10),
    'STACK_4_CELL_3_VOLTAGE': (-10, 10),
    'STACK_4_CELL_4_VOLTAGE': (-10, 10),
    'STACK_5_CELL_1_VOLTAGE': (-10, 10),
    'STACK_5_CELL_2_VOLTAGE': (-10, 10),
    'STACK_5_CELL_3_VOLTAGE': (-10, 10),
    'STACK_5_CELL_4_VOLTAGE': (-10, 10),
    'STACK_6_CELL_1_VOLTAGE': (-10, 10),
    'STACK_6_CELL_2_VOLTAGE': (-10, 10),
    'STACK_6_CELL_3_VOLTAGE': (-10, 10),
    'STACK_6_CELL_4_VOLTAGE': (-10, 10),
    'STACK_1_CELL_1_TEMPERATURE': (-10, 100),
    'STACK_1_CELL_2_TEMPERATURE': (-10, 100),
    'STACK_1_CELL_3_TEMPERATURE': (-10, 100),
    'STACK_1_CELL_4_TEMPERATURE': (-10, 100),
    'STACK_2_CELL_1_TEMPERATURE': (-10, 100),
    'STACK_2_CELL_2_TEMPERATURE': (-10, 100),
    'STACK_2_CELL_3_TEMPERATURE': (-10, 100),
    'STACK_2_CELL_4_TEMPERATURE': (-10, 100),
    'STACK_3_CELL_1_TEMPERATURE': (-10, 100),
    'STACK_3_CELL_2_TEMPERATURE': (-10, 100),
    'STACK_3_CELL_3_TEMPERATURE': (-10, 100),
    'STACK_3_CELL_4_TEMPERATURE': (-10, 100),
    'STACK_4_CELL_1_TEMPERATURE': (-10, 100),
    'STACK_4_CELL_2_TEMPERATURE': (-10, 100),
    'STACK_4_CELL_3_TEMPERATURE': (-10, 100),
    'STACK_4_CELL_4_TEMPERATURE': (-10, 100),
    'STACK_5_CELL_1_TEMPERATURE': (-10, 100),
    'STACK_5_CELL_2_TEMPERATURE': (-10, 100),
    'STACK_5_CELL_3_TEMPERATURE': (-10, 100),
    'STACK_5_CELL_4_TEMPERATURE': (-10, 100),
    'STACK_6_CELL_1_TEMPERATURE': (-10, 100),
    'STACK_6_CELL_2_TEMPERATURE': (-10, 100),
    'STACK_6_CELL_3_TEMPERATURE': (-10, 100),
    'STACK_6_CELL_4_TEMPERATURE': (-10, 100),
    'BMS_ERRORMASK': (None, None),
    'BMS_ERROR_LOG1': (None, None),
    'BMS_ERROR_LOG2': (None, None),
    'BMS_ERROR_LOG3': (None, None),
    'BMS_ERROR_LOG4': (None, None),
    'BMS_ERROR_LOG5': (None, None),
    'ERROR_SUM_S1': (None, None),
    'ERROR_SUM_S2': (None, None),
    'ERROR_SUM_S3': (None, None),
    'ERROR_SUM_S4': (None, None),
    'ERROR_SUM_S5': (None, None),
    'ERROR_SUM_S6': (None, None),
    'BMS_MODE': (None, None),
    'ADDR_CELL_VOLT_MIN': (-10, 10),
    'ADDR_STACK_VOLT_MIN': (-10, 10),
    'ADDR_MIN_VOLTAGE': (-10, 10),
    'ADDR_CELL_VOLT_MAX': (-10, 10),
    'ADDR_STACK_VOLT_MAX': (-10, 10),
    'ADDR_MAX_VOLTAGE': (-10, 10),
    'ADDR_CELL_TEMP_MAX': (-10, 10),
    'ADDR_STACK_TEMP_MAX': (-10, 10),
    'ADDR_MAX_TEMPERATURE': (-10, 100),
    'DESIRED_YAW': (None, None),
    'MAX_YAW': (None, None),
    'ECU_MODE': (-10, 10),
    'CONTROL_EVENT_FLAG_1': (None, None),
    'CONTROL_EVENT_FLAG_2': (None, None),
    'DISTANCE_P_ODOM': (None, None),
    'SET_POINT_LONGITUDINAL': (None, None),
    'SET_POINT_LATERAL': (None, None),
    'KP': (None, None),
    'TI': (None, None),
    'SLIP': (None, None),
    'RIGHT_MOTOR_TEMPERATURE': (-10, 100),
    'LEFT_MOTOR_TEMPERATURE': (-10, 100),
}

# %%
# passa pelos fulls: remove timestamps que estão fora dos ranges
def is_in_range(timestamp):
    for key in interest_timestamps:
        start_date, end_date = interest_timestamps[key]
        
        if isinstance(start_date, str):
            start_timestamp = datetime.strptime(start_date, "%Y-%m-%d %H:%M:%S").timestamp() * 1000
            end_timestamp = datetime.strptime(end_date, "%Y-%m-%d %H:%M:%S").timestamp() * 1000
        else:
            start_timestamp = start_date
            end_timestamp = end_date

        if timestamp >= start_timestamp and timestamp <= end_timestamp:
            return True, key
        
    return False, None

for i in range(len(file_names)):
    file_names[i] = "FULL_" + file_names[i]

for file_name in file_names:
    print(file_name + "...")

    # verifica se existe na lista do file_columns_map
    if file_name not in file_columns_map:
        continue

    # le o arquivo atual
    df = pd.read_csv(f'{full_folder}/{file_name}')

    # monta o dicionario de dados desse arquivo
    data_row = {}

    for column in columns:
        data_row[column] = []

    # varre os timestamps
    for i in range (df.shape[0]):
        curr_timestamp = df.iloc[i, 1] 
        is_range, key = is_in_range(timestamp=curr_timestamp)
        
        if is_range:
            # pega as colunas desse arquivo
            columns_to_add = file_columns_map[file_name]

            # para cada coluna do full_df
            for col in full_df.columns:
                if col == 'timestamp': 
                    data_row['timestamp'].append(curr_timestamp)
                    continue 

                # verifica se essa coluna tem dados para adicionar
                if col in columns_to_add:
                    # se o arquivo atual esta na lista de refatoração
                    if file_name in columns_rename_map:
                        refactor_list = columns_rename_map[file_name]
                        result = next((item for item in refactor_list if item[1] == col), None)

                        if result == None:
                            # a coluna atual nao precisa de refatoração
                            data_row[col].append(df.iloc[i][col])
                            continue
                        
                        old_name, new_name = result
                        data_row[new_name].append(df.iloc[i][old_name])
                    else:
                        data_row[col].append(df.iloc[i][col])
                else:
                    # sem dados para adicionar
                    data_row[col].append(np.nan)

    # salva o dicionario na full_df
    new_rows = pd.DataFrame(data_row)
    full_df = pd.concat([full_df, new_rows], ignore_index=True)

print("full_df done...")
# Out:
# FULL_1_GYROSCOPE.csv...
# FULL_2_ACCELEROMETER.csv...
# FULL_8_AIR_GVL_CURRENT.csv...
# FULL_10_TOTAL_VOLTAGE_STACK_46.csv...
# FULL_11_ACCUMULATOR_PARAMS.csv...
# FULL_12_GNSS_TIMESTAMP.csv...
# FULL_13_GNSS_LATITUDE.csv...
# FULL_14_GNSS_LONGITUDE.csv...
# FULL_16_DRIVER_INPUTS.csv...
# FULL_17_REF_TORQUE.csv...
# FULL_18_WHEEL_SPEED.csv...
# FULL_20_LEFT_MOTOR_TRACTIVE.csv...
# FULL_21_LEFT_MOTOR_CURRENT.csv...
# FULL_25_RIGHT_MOTOR_TRACTIVE.csv...
# FULL_26_RIGHT_MOTOR_CURRENT.csv...
# FULL_27_RIGHT_MOTOR_ENERGY_TEMP.csv...
# FULL_28_RIGHT_MOTOR_COMMUNICATION.csv...
# FULL_29_RIGHT_MOTOR_STATE.csv...
# FULL_34_STACK_VOLTAGE_1.csv...
# FULL_35_STACK_VOLTAGE_2.csv...
# FULL_36_STACK_VOLTAGE_3.csv...
# FULL_37_STACK_VOLTAGE_4.csv...
# FULL_38_STACK_VOLTAGE_5.csv...
# FULL_39_STACK_VOLTAGE_6.csv...
# FULL_40_STACK_TEMPERATURE_1.csv...
# FULL_41_STACK_TEMPERATURE_2.csv...
# FULL_42_STACK_TEMPERATURE_3.csv...
# FULL_43_STACK_TEMPERATURE_4.csv...
# FULL_44_STACK_TEMPERATURE_5.csv...
# FULL_45_STACK_TEMPERATURE_6.csv...
# FULL_46_BMS_ERROR_LOG_1.csv...
# FULL_47_BMS_ERROR_LOG_2.csv...
# FULL_48_ERROR_SUM_SLAVE_1.csv...
# FULL_49_ERROR_SUM_SLAVE_2.csv...
# FULL_50_BMS_MODE.csv...
# FULL_63_ADDR_VOLT_MIN.csv...
# FULL_64_ADDR_VOLT_MAX.csv...
# FULL_65_ADDR_MAX_TEMP.csv...
# FULL_66_DESIRED_YAW.csv...
# FULL_67_ECU_MODE.csv...
# FULL_68_TORQUE_GAIN.csv...
# FULL_69_CONTROL_EVENTS.csv...
# FULL_70_HODOMETER.csv...
# FULL_71_SET_POINT.csv...
# FULL_72_SLIP_RATE.csv...
# FULL_73_TEMPERATURE_NTC_1.csv...
# full_df done...

# %%
# ordena o df por timestamp
sorted_df = full_df.sort_values(by='timestamp')
print("sorted_df done...")

# agrupa e toma a media de timestamps duplicados
grouped_df = sorted_df.groupby('timestamp', as_index=False).mean()
print("grouped_df done...")

if grouped_df.shape[0] == 0 or grouped_df.shape[1] == 0:
    raise ValueError("Erro: grouped_df está vazio.")
# Out:
# sorted_df done...
# grouped_df done...
# /tmp/ipykernel_54590/1438232206.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   grouped_df = sorted_df.groupby('timestamp', as_index=False).mean()

# %%
# zera as medições NA da primeira linha
for j in range(grouped_df.shape[1]):
    if pd.isna(grouped_df.iloc[0, j]):
        grouped_df.iloc[0, j] = 0

# remover os NA puxando o valor do timestamp anterior
# filled_df = grouped_df.fillna(method='ffill')
filled_df = grouped_df.ffill()
print("filled_df done...")
# Out:
# filled_df done...

# %%
print(filled_df.columns.tolist())
# Out:
# ['timestamp', 'ACCEL_LONGITUDINAL', 'ACCEL_LATERAL', 'ACCEL_NORMAL', 'VEL_ANGULAR_YAW', 'VEL_ANGULAR_PITCH', 'VEL_ANGULAR_ROLL', 'AIR_MINUS', 'AIR_PLUS', 'GLV_VOLTAGE', 'SHUNT_CURRENT', 'MAX_CELL_VOLTAGE', 'MIN_CELL_VOLTAGE', 'MAX_CELL_TEMP', 'TRACTIVE_VOLTAGE', 'GNSS_TIMESTAMP', 'LATITUDE', 'LONGITUDE', 'SPEED_AVG', 'STEERING_WHEEL', 'THROTTLE', 'BRAKE', 'TORQUE_GAIN', 'TORQUE_DECREASE_R', 'TORQUE_DECREASE_L', 'SPEED_FL', 'SPEED_FR', 'SPEED_RL', 'SPEED_RR', 'RPM_L_MOTOR', 'TORQUE_L_MOTOR', 'POWER_L_MOTOR', 'LEFT_MOTOR_CURRENT', 'RPM_R_MOTOR', 'TORQUE_R_MOTOR', 'POWER_R_MOTOR', 'RIGHT_MOTOR_CURRENT', 'ENERGY_R_MOTOR', 'OVERLOAD_R_MOTOR', 'TEMPERATURE1_R', 'TEMPERATURE2_R', 'LOST_MSG_R_MOTOR', 'BUS_OFF_R_MOTOR', 'CAN_STATE_R_MOTOR', 'INV_STATE_R_MOTOR', 'FAILURE_R_MOTOR', 'ALARM_R_MOTOR', 'BMS_ERRORMASK', 'BMS_ERROR_LOG1', 'BMS_ERROR_LOG2', 'BMS_ERROR_LOG3', 'BMS_ERROR_LOG4', 'BMS_ERROR_LOG5', 'ERROR_SUM_S1', 'ERROR_SUM_S2', 'ERROR_SUM_S3', 'ERROR_SUM_S4', 'ERROR_SUM_S5', 'BMS_MODE', 'ADDR_CELL_VOLT_MIN', 'ADDR_STACK_VOLT_MIN', 'ADDR_MIN_VOLTAGE', 'ADDR_CELL_VOLT_MAX', 'ADDR_STACK_VOLT_MAX', 'ADDR_MAX_VOLTAGE', 'ADDR_CELL_TEMP_MAX', 'ADDR_STACK_TEMP_MAX', 'ADDR_MAX_TEMPERATURE', 'DESIRED_YAW', 'MAX_YAW', 'ECU_MODE', 'CONTROL_EVENT_FLAG_1', 'CONTROL_EVENT_FLAG_2', 'DISTANCE_P_ODOM', 'DISTANCE_T_ODOM', 'SET_POINT_LONGITUDINAL', 'SET_POINT_LATERAL', 'KP', 'TI', 'SLIP', 'RIGHT_MOTOR_TEMPERATURE', 'LEFT_MOTOR_TEMPERATURE', 'STACK_1_CELL_1_VOLTAGE', 'STACK_1_CELL_2_VOLTAGE', 'STACK_1_CELL_3_VOLTAGE', 'STACK_1_CELL_4_VOLTAGE', 'STACK_2_CELL_1_VOLTAGE', 'STACK_2_CELL_2_VOLTAGE', 'STACK_2_CELL_3_VOLTAGE', 'STACK_2_CELL_4_VOLTAGE', 'STACK_3_CELL_1_VOLTAGE', 'STACK_3_CELL_2_VOLTAGE', 'STACK_3_CELL_3_VOLTAGE', 'STACK_3_CELL_4_VOLTAGE', 'STACK_4_CELL_1_VOLTAGE', 'STACK_4_CELL_2_VOLTAGE', 'STACK_4_CELL_3_VOLTAGE', 'STACK_4_CELL_4_VOLTAGE', 'STACK_5_CELL_1_VOLTAGE', 'STACK_5_CELL_2_VOLTAGE', 'STACK_5_CELL_3_VOLTAGE', 'STACK_5_CELL_4_VOLTAGE', 'STACK_6_CELL_1_VOLTAGE', 'STACK_6_CELL_2_VOLTAGE', 'STACK_6_CELL_3_VOLTAGE', 'STACK_6_CELL_4_VOLTAGE', 'STACK_1_CELL_1_TEMPERATURE', 'STACK_1_CELL_2_TEMPERATURE', 'STACK_1_CELL_3_TEMPERATURE', 'STACK_1_CELL_4_TEMPERATURE', 'STACK_2_CELL_1_TEMPERATURE', 'STACK_2_CELL_2_TEMPERATURE', 'STACK_2_CELL_3_TEMPERATURE', 'STACK_2_CELL_4_TEMPERATURE', 'STACK_3_CELL_1_TEMPERATURE', 'STACK_3_CELL_2_TEMPERATURE', 'STACK_3_CELL_3_TEMPERATURE', 'STACK_3_CELL_4_TEMPERATURE', 'STACK_4_CELL_1_TEMPERATURE', 'STACK_4_CELL_2_TEMPERATURE', 'STACK_4_CELL_3_TEMPERATURE', 'STACK_4_CELL_4_TEMPERATURE', 'STACK_5_CELL_1_TEMPERATURE', 'STACK_5_CELL_2_TEMPERATURE', 'STACK_5_CELL_3_TEMPERATURE', 'STACK_5_CELL_4_TEMPERATURE', 'STACK_6_CELL_1_TEMPERATURE', 'STACK_6_CELL_2_TEMPERATURE', 'STACK_6_CELL_3_TEMPERATURE', 'STACK_6_CELL_4_TEMPERATURE']

# %%
TRANSMISSION_RATIO = 8.89
WHEEL_RADIUS = 20.5 * 2.54 / 2 / 100
PI = 3.1415
MS_TO_KPH = 3.6
SHUNT_OFFSET = 0
ACCEL_SENSITIVITY_FACTOR = 0.122 / 1000
GYRO_SENSITIVITY_FACTOR = 70 / 1000
FRONT_PHONIC_WHEEL_FACTOR = 1 / 10
TORQUE_SCALING_FACTOR = 13 / 1000
CURRENT_SCALING_FACTOR = 1 / 10

# formata grandezas fisica, add colunas extras manualmente
filled_df['t'] = filled_df['timestamp'] - filled_df['timestamp'][0]
filled_df['MAX_CELL_VOLTAGE'] = filled_df['MAX_CELL_VOLTAGE'] / 10000
filled_df['MIN_CELL_VOLTAGE'] = filled_df['MIN_CELL_VOLTAGE'] / 10000
filled_df['MAX_CELL_TEMP'] = filled_df['MAX_CELL_TEMP'] / 10
filled_df['TORQUE_GAIN'] = filled_df['TORQUE_GAIN'] * TORQUE_SCALING_FACTOR
filled_df['TORQUE_DECREASE_L'] = filled_df['TORQUE_DECREASE_L'] * TORQUE_SCALING_FACTOR
filled_df['TORQUE_DECREASE_R'] = filled_df['TORQUE_DECREASE_R'] * TORQUE_SCALING_FACTOR
filled_df['TORQUE_L_MOTOR'] = filled_df['TORQUE_L_MOTOR'] * TORQUE_SCALING_FACTOR
filled_df['TORQUE_R_MOTOR'] = filled_df['TORQUE_R_MOTOR'] * TORQUE_SCALING_FACTOR
filled_df['LEFT_MOTOR_CURRENT'] = filled_df['LEFT_MOTOR_CURRENT'] * CURRENT_SCALING_FACTOR
filled_df['RIGHT_MOTOR_CURRENT'] = filled_df['RIGHT_MOTOR_CURRENT'] * CURRENT_SCALING_FACTOR
filled_df['TEMPERATURE1_R'] = filled_df['TEMPERATURE1_R'] / 10

# %%
filled_df.columns
# Out:
# Index(['timestamp', 'ACCEL_LONGITUDINAL', 'ACCEL_LATERAL', 'ACCEL_NORMAL',
#        'VEL_ANGULAR_YAW', 'VEL_ANGULAR_PITCH', 'VEL_ANGULAR_ROLL', 'AIR_MINUS',
#        'AIR_PLUS', 'GLV_VOLTAGE',
#        ...
#        'STACK_4_CELL_4_TEMPERATURE', 'STACK_5_CELL_1_TEMPERATURE',
#        'STACK_5_CELL_2_TEMPERATURE', 'STACK_5_CELL_3_TEMPERATURE',
#        'STACK_5_CELL_4_TEMPERATURE', 'STACK_6_CELL_1_TEMPERATURE',
#        'STACK_6_CELL_2_TEMPERATURE', 'STACK_6_CELL_3_TEMPERATURE',
#        'STACK_6_CELL_4_TEMPERATURE', 't'],
#       dtype='str', length=131)

# %%
# remove dados de ruidos / absurdos
for i in range(1, filled_df.shape[0]):
    if i % (filled_df.shape[0] / 10) == 0:
        print(f"Completo {i / filled_df.shape[0] * 100:.2f}%")

    for key in columns_list_threshholds:
        min_limit, max_limit = columns_list_threshholds[key]

        if max_limit == None or min_limit == None:
            continue
           
        if filled_df.loc[i, key] > max_limit or filled_df.loc[i, key] < min_limit:
            filled_df.loc[i, key] = filled_df.loc[i-1, key]

# %%
# calcula a distancia percorrida - hodometro
hodometro = [0]

# para cada entrada no df
for i in range(1, filled_df.shape[0]):
    if i % (filled_df.shape[0] / 10) == 0:
        print(f"Completo {i / filled_df.shape[0] * 100:.2f}%")

    ## ------ PROCEDIMENTO GERAL ------- ###
    # se os AIRs estao fechados
    if filled_df.iloc[i]['AIR_PLUS'] == 1 and filled_df.iloc[i]['AIR_MINUS'] == 1:
        # soma a distancia percorrida desde o ultimo timestamp
        delta_t = (filled_df.iloc[i]['t'] - filled_df.iloc[i - 1]['t']) / 1000  # em segundos

        # usa as rodas fonicas dianteiras
        curr_speed_ms = filled_df.iloc[i]['SPEED_AVG'] / 3.6  # converte para m/s
        prev_speed_ms = filled_df.iloc[i - 1]['SPEED_AVG'] / 3.6 # converte para m/s

        distance_increment = ((curr_speed_ms + prev_speed_ms) / 2) * delta_t
        hodometro.append(hodometro[-1] + distance_increment)
    else:
        # so pega o valor anterior: estamos sem AIRs e com ECU_MODE_ID == 0 - falha
        hodometro.append(hodometro[-1])

filled_df['HODOMETRO'] = hodometro

# %%
# faz o split e salva em cada CSV
for key in interest_timestamps:
    folder = key.split("_")[0]
    
    start_date, end_date = interest_timestamps[key]
    
    if isinstance(start_date, str):
        start_timestamp = datetime.strptime(start_date, "%Y-%m-%d %H:%M:%S").timestamp() * 1000
        end_timestamp = datetime.strptime(end_date, "%Y-%m-%d %H:%M:%S").timestamp() * 1000
    else:
        start_timestamp = start_date
        end_timestamp = end_date

    splitted_df = filled_df[(filled_df["timestamp"] >= start_timestamp) & (filled_df["timestamp"] < end_timestamp)]

    splitted_df.to_csv(f'{full_folder}/{folder}/{key}.csv', index=False)

# salva o df final para um CSV novo
filled_df.to_csv(f'{full_folder}/full_df.csv', index=False)
